# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("C:\\Users\\bingi\\Downloads\\titanic\\test.csv")
df1.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df2 = pd.read_csv("C:\\Users\\bingi\\Downloads\\titanic\\gender_submission.csv")

data = pd.merge(df1 , df2 , how = 'left' , on = 'PassengerId')

data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Survived
# 0  34.5      0      0   330911   7.8292   NaN        Q         0
# 1  47.0      1      0   363272   7.0000   NaN        S         1
# 2  62.0      0      0   240276   9.6875   NaN        Q         0
# 3  27.0      0      0   315154   8.6625   NaN        S         0
# 4  22.0      1      1  3101298  12.2875   NaN        S         1

# %%
data.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Survived'],
#       dtype='object')

# %%
data.shape
# Out:
# (418, 12)

# %%
cols = list(data.columns)

last_col = cols.pop(-1)
cols.insert(1 , last_col)

data = data[cols]

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df1 = pd.read_csv("C:\\Users\\bingi\\Downloads\\titanic\\train.csv")
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df1.shape
# Out:
# (891, 12)

# %%
df = pd.concat([df1 , data], ignore_index = True)
df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1         0       3
# 1               2         1       1
# 2               3         1       3
# 3               4         1       1
# 4               5         0       3
# ...           ...       ...     ...
# 1304         1305         0       3
# 1305         1306         1       1
# 1306         1307         0       3
# 1307         1308         0       3
# 1308         1309         0       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.shape
# Out:
# (1309, 12)

# %%
df.isnull().sum()
# Out:
# PassengerId       0
# Survived          0
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
df.drop(columns = ['Cabin'] , inplace = True)
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
print(df['Sex'].value_counts())
print(df[['Sex' , 'Survived']].value_counts())
# Out:
# Sex
# male      843
# female    466
# Name: count, dtype: int64
# Sex     Survived
# male    0           734
# female  1           385
# male    1           109
# female  0            81
# Name: count, dtype: int64

# %%
df['Is_Alone'] = ((df['SibSp'] == 0) & (df['Parch'] == 0)).astype(int)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  Is_Alone
# 0      0         A/5 21171   7.2500        S         0
# 1      0          PC 17599  71.2833        C         0
# 2      0  STON/O2. 3101282   7.9250        S         1
# 3      0            113803  53.1000        S         0
# ...

# %%
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1

print(df[['PassengerId','SibSp','Parch','FamilySize' , 'Is_Alone']].head(10))
# Out:
#    PassengerId  SibSp  Parch  FamilySize  Is_Alone
# 0            1      1      0           2         0
# 1            2      1      0           2         0
# 2            3      0      0           1         1
# 3            4      1      0           2         0
# 4            5      0      0           1         1
# 5            6      0      0           1         1
# 6            7      0      0           1         1
# 7            8      3      1           5         0
# 8            9      0      2           3         0
# 9           10      1      0           2         0

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  Is_Alone  Family_Size  \
# 0      0         A/5 21171   7.2500        S         0            1
# 1      0          PC 17599  71.2833        C         0            1
# 2      0  STON/O2. 3101282   7.9250        S         1            0
# ...

# %%
df['Is_Alone'].value_counts()
# Out:
# Is_Alone
# 1    790
# 0    519
# Name: count, dtype: int64

# %%
df.loc[df['Fare'].idxmax()]
# Out:
# PassengerId                 259
# Survived                      1
# Pclass                        1
# Name           Ward, Miss. Anna
# Sex                      female
# Age                        35.0
# SibSp                         0
# Parch                         0
# Ticket                 PC 17755
# Fare                   512.3292
# Embarked                      C
# Is_Alone                      1
# Family_Size                   0
# FamilySize                    1
# Name: 258, dtype: object

# %%
df.describe()
# Out:
#        PassengerId     Survived       Pclass          Age        SibSp  \
# count  1309.000000  1309.000000  1309.000000  1046.000000  1309.000000
# mean    655.000000     0.377387     2.294882    29.881138     0.498854
# std     378.020061     0.484918     0.837836    14.413493     1.041658
# min       1.000000     0.000000     1.000000     0.170000     0.000000
# 25%     328.000000     0.000000     2.000000    21.000000     0.000000
# 50%     655.000000     0.000000     3.000000    28.000000     0.000000
# 75%     982.000000     1.000000     3.000000    39.000000     1.000000
# max    1309.000000     1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare     Is_Alone  Family_Size   FamilySize
# count  1309.000000  1308.000000  1309.000000  1309.000000  1309.000000
# mean      0.385027    33.295479     0.603514     0.317036     1.883881
# std       0.865560    51.758668     0.489354     0.595235     1.583639
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     1309 non-null   int64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Embarked     1307 non-null   object
#  11  Is_Alone     1309 non-null   int64
#  12  Family_Size  1309 non-null   int64
#  13  FamilySize   1309 non-null   int64
# dtypes: float64(2), int64(8), object(4)
# memory usage: 143.3+ KB

# %%
import plotly.express as px

fig = px.histogram(
    df,
    x='Sex',
    color='Survived',
    title='Survival by Sex'
)

fig.update_layout(
    xaxis_title='Sex',
    yaxis_title='Count'
)

fig.show()

# %%
survived_counts = df['Survived'].value_counts()

plt.figure(figsize=(6,6))
plt.pie(
    survived_counts,
    labels=['Did Not Survive','Survived'],
    autopct='%1.1f%%',
    colors=['red','green'],
    startangle=90
)

plt.title('Survival Distribution')
plt.show()

# %%
px.pie(df, names='Pclass', title='Passenger Class Distribution')

# %%
sns.histplot(data=df, x='Age', bins=20, kde=True, color='blue')

plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution of Passengers')
plt.show()

# %%
sns.countplot(data=df, x='Pclass', hue='Survived')
plt.title('Survival Count by Passenger Class')
plt.show()

# %%
sns.countplot(data=df, x='Is_Alone', hue='Survived')
plt.title('Survival Count: Alone vs Not Alone')
plt.xticks([0,1], ['Not Alone','Alone'])
plt.show()

# %%
numerical_col = df.select_dtypes(include='number')

corr = numerical_col.corr()

plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True, cmap='Blues', fmt=".2f")

plt.title('Correlation Heatmap of Numeric Features')
plt.show()
